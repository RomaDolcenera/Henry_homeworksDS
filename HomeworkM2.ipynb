# %% [markdown]
# # Práctica Clase 2

# %% [markdown]
# 1) Abrir el archivo "Emisiones_CO2.csv" y cargar sus datos en un diccionario.

# %%
import os
archivo = open('Emisiones_CO2.csv', 'r')

# %%
dicc_emisiones = {  'cod_pais' : [],
                    'nom_pais' : [],
                    'region' : [],
                    'anio' : [],
                    'co2' : [],
                    'co2_percapita' : []}

# %%
next(archivo)  #next permite saltar una linea asi que le decimos
for linea in archivo:
    linea = linea.strip()  #borramos el \n del final
    campos = linea.split('|')
    #ejecutar cada indice para asignarlo a la lista
    dicc_emisiones['cod_pais'].append(campos[0])
    dicc_emisiones['nom_pais'].append(campos[1])
    dicc_emisiones['region'].append(campos[2])
    dicc_emisiones['anio'].append(campos[3])
    dicc_emisiones['co2'].append(campos[4])
    dicc_emisiones['co2_percapita'].append(campos[5])

# %%
dicc_emisiones['cod_pais'] #llamar al diccionario solo el codigo pais.
# Out:
# ['ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
#  'AND',
# ...

# %%
archivo.close()  #cerramos el archivo pora que no quede abierto en el buffer.

# %% [markdown]
# 2) a) ¿Cuántas variables hay? <br>
# b) ¿Qué tipos de datos usar para cada una? <br>
# c) ¿Qué tipo de variables son? <br>
# d) ¿Hay valores faltantes? <br>
# e) ¿Cuál es el total de emisiones de CO2 para 'América Latina y Caribe' en el año 2010?

# %% [markdown]
# # RESPUESTAS
#
#  a) hay 6 variables
#  b)   srtings - interger, float
#  c)cod pais=cuantitativa categorica
#    nom del pais = categorico
#    region = categorico
#    anio = cualitativo discreto
#    co2 percapita = cuantitativo continuo
#  d) Si, existen valores faltantes.
#  e)

# %%
# Casteo año como interger A Traves de iteradores
for i in range(len(dicc_emisiones['anio'])):
    dicc_emisiones['anio'][i] = int(dicc_emisiones['anio'][i])

# %%
dicc_emisiones['anio'][50]  #Prueba que funciona correctamente.
# Out:
# 2010

# %%
for indice, elemento in enumerate(dicc_emisiones['co2']): 
   elemento = elemento.replace('.', '')
   elemento = elemento.replace(',', '.')
   if elemento:
      elemento = float(elemento)
   else:
      elemento = None
   dicc_emisiones['co2'][indice] = elemento

# %%
dicc_emisiones['co2'][38] #prueba que funciona correctamente.
# Out:
# 1712.49

# %%
print(dicc_emisiones['co2'][18]) #prueba que funciona correctamente
# Out:
# None

# %%
for indice, elemento in enumerate(dicc_emisiones['co2_percapita']): 
   elemento = elemento.replace('.' ,  '')
   elemento = elemento.replace(',' ,  '.')
   if elemento:
      elemento = float(elemento)
   else:
      elemento = None
   dicc_emisiones['co2_percapita'][indice] = elemento

# %%
print(dicc_emisiones['co2_percapita'][38])
# Out:
# 19.621533984

# %%
filtro_region = 'América Latina y Caribe'
filtro_anio = 2010
total_emisiones = 0
for indice, elemento in enumerate(dicc_emisiones['region']):  #Filtro los datos que estan vacios
    if dicc_emisiones['region'][indice] == filtro_region and dicc_emisiones['anio'][indice] == filtro_anio and dicc_emisiones['co2'][indice]!= None:
        total_emisiones += dicc_emisiones['co2'][indice]
        
print(total_emisiones)
# Out:
# 1691634.8009999995
